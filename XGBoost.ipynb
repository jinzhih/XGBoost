# %%
from sklearn.datasets import load_boston
boston = load_boston()

# %%
print(boston.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
print(boston.data.shape)
# Out:
# (506, 13)

# %%
print(boston.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
import pandas as pd

data = pd.DataFrame(boston.data)
data.columns = boston.feature_names

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
data['PRICE'] = boston.target

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  PRICE    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT       PRICE
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np

# %%
# !pip3 install xgboost
# Out:
# Collecting xgboost
#   Using cached https://files.pythonhosted.org/packages/33/c8/711e56c5561ffd4b72908d1bb6039900bb537b0d6416d7d597bef30c94fe/xgboost-1.3.2-py3-none-macosx_10_14_x86_64.macosx_10_15_x86_64.macosx_11_0_x86_64.whl
# Collecting scipy (from xgboost)
#   Downloading https://files.pythonhosted.org/packages/33/a4/6469cbec8e5ac5fe26c5ccbdcccbbf6a6c0aab7968fcdeac617c8704dc51/scipy-1.6.0-cp37-cp37m-macosx_10_9_x86_64.whl (30.7MB)
#     100% |████████████████████████████████| 30.7MB 1.2MB/s ta 0:00:011
# Collecting numpy (from xgboost)
#   Downloading https://files.pythonhosted.org/packages/39/ba/f3db2b5bb36fee2478b1cf47e7f9664b9c27241be80acd31c844404da297/numpy-1.19.5-cp37-cp37m-macosx_10_9_x86_64.whl (15.6MB)
#     100% |████████████████████████████████| 15.6MB 2.0MB/s ta 0:00:011
# Installing collected packages: numpy, scipy, xgboost
# Could not install packages due to an EnvironmentError: [Errno 13] Permission denied: '/Library/Python/3.7'
# Consider using the `--user` option or check the permissions.
#
# You are using pip version 19.0.3, however version 20.3.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Out:
#   File "<ipython-input-2-7dae35fcc48e>", line 1
#     sudo !pip3 install xgboost
#          ^
# SyntaxError: invalid syntax

# %%
pip install --upgrade pip
# Out:
# Collecting pip
#   Downloading pip-20.3.3-py2.py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 3.6 MB/s eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 20.0.2
#     Uninstalling pip-20.0.2:
#       Successfully uninstalled pip-20.0.2
# Successfully installed pip-20.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update conda
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::matplotlib==3.1.3=py37_0
#   - defaults/osx-64::spyder==4.0.1=py37_0
#   - defaults/osx-64::conda-package-handling==1.6.0=py37h1de35cc_0
#   - defaults/noarch::sphinx==2.4.0=py_0
#   - defaults/osx-64::conda==4.8.2=py37_0
#   - defaults/noarch::anaconda-project==0.8.4=py_0
#   - defaults/osx-64::anaconda-navigator==1.9.12=py37_0
#   - defaults/osx-64::bkcharts==0.2=py37_0
#   - defaults/osx-64::statsmodels==0.11.0=py37h1de35cc_0
#   - defaults/osx-64::conda-build==3.18.11=py37_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/osx-64::scikit-image==0.16.2=py37h6c726b0_0
#   - defaults/osx-64::anaconda-client==1.7.2=py37_0
#   - defaults/noarch::numpydoc==0.9.2=py_0
#   - defaults/osx-64::anaconda==2020.02=py37_0
#   - defaults/noarch::dask==2.11.0=py_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/jinhou/opt/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2020.07  |           py37_0           6 KB
#     appnope-0.1.2              |py37hecd8cb5_1001          10 KB
#     appscript-1.1.1            |   py37haf1e3a3_0         130 KB
#     argon2-cffi-20.1.0         |   py37haf1e3a3_1          44 KB
#     asn1crypto-1.4.0           |             py_0          80 KB
#     astroid-2.4.2              |           py37_0         279 KB
#     astropy-4.2                |   py37h9ed2024_0         6.0 MB
#     async_generator-1.10       |   py37h28b3542_0          39 KB
#     atomicwrites-1.4.0         |             py_0          11 KB
#     attrs-20.3.0               |     pyhd3eb1b0_0          43 KB
#     autopep8-1.5.4             |             py_0          42 KB
#     babel-2.9.0                |     pyhd3eb1b0_0         5.5 MB
#     backcall-0.2.0             |             py_0          15 KB
#     backports-1.0              |     pyhd3eb1b0_2         210 KB
#     backports.functools_lru_cache-1.6.1|     pyhd3eb1b0_0          12 KB
#     backports.shutil_get_terminal_size-1.0.0|     pyhd3eb1b0_3          10 KB
#     beautifulsoup4-4.9.3       |     pyhb0f4dca_0          91 KB
#     bitarray-1.6.1             |   py37h9ed2024_0          87 KB
#     bleach-3.2.1               |             py_0         112 KB
#     blosc-1.20.1               |       hab81aa3_0          56 KB
#     bokeh-2.2.3                |           py37_0         5.3 MB
#     bottleneck-1.3.2           |   py37hf1fa96c_1         107 KB
#     brotlipy-0.7.0             |py37h9ed2024_1003         333 KB
#     cffi-1.14.4                |   py37h2125817_0         214 KB
#     chardet-4.0.0              |py37hecd8cb5_1003         194 KB
#     click-7.1.2                |             py_0          71 KB
#     cloudpickle-1.6.0          |             py_0          30 KB
#     colorama-0.4.4             |     pyhd3eb1b0_0          21 KB
#     cryptography-3.3.1         |   py37hbcfaee0_0         554 KB
#     curl-7.71.1                |       hb0a8c7a_1         129 KB
#     cython-0.29.21             |   py37h23ab428_0         1.8 MB
#     cytoolz-0.11.0             |   py37haf1e3a3_0         289 KB
#     dbus-1.13.18               |       h18a8e69_0         445 KB
#     decorator-4.4.2            |             py_0          14 KB
#     diff-match-patch-20200713  |             py_0          36 KB
#     distributed-2.30.1         |   py37hecd8cb5_0        1010 KB
#     docutils-0.16              |           py37_1         667 KB
#     et_xmlfile-1.0.1           |          py_1001          12 KB
#     expat-2.2.10               |       hb1e8313_2         110 KB
#     flake8-3.8.4               |             py_0         128 KB
#     flask-1.1.2                |             py_0          78 KB
#     freetype-2.10.4            |       ha233b18_0         564 KB
#     fsspec-0.8.3               |             py_0          72 KB
#     future-0.18.2              |           py37_1         630 KB
#     gettext-0.19.8.1           |       hb0f4f8b_2         2.7 MB
#     gevent-20.12.1             |   py37h9ed2024_1         1.5 MB
#     glib-2.66.1                |       h9bbe63b_0         2.7 MB
#     greenlet-0.4.17            |   py37haf1e3a3_0          20 KB
#     html5lib-1.1               |             py_0          93 KB
#     icu-58.2                   |       h0a44026_3        10.1 MB
#     idna-2.10                  |             py_0          50 KB
#     imageio-2.9.0              |             py_0         3.0 MB
#     importlib-metadata-2.0.0   |             py_1          35 KB
#     importlib_metadata-2.0.0   |                1          11 KB
#     iniconfig-1.1.1            |             py_0           9 KB
#     intervaltree-3.1.0         |             py_0          26 KB
#     ipykernel-5.3.4            |   py37h5ca1d4c_0         182 KB
#     ipython-7.19.0             |   py37h01d92e1_1        1004 KB
#     ipython_genutils-0.2.0     |     pyhd3eb1b0_1          27 KB
#     ipywidgets-7.6.3           |     pyhd3eb1b0_1         105 KB
#     isort-5.6.4                |             py_0          78 KB
#     jinja2-2.11.2              |             py_0         103 KB
#     joblib-1.0.0               |     pyhd3eb1b0_0         208 KB
#     json5-0.9.5                |             py_0          22 KB
#     jsonschema-3.2.0           |             py_2          47 KB
#     jupyter_client-6.1.7       |             py_0          77 KB
#     jupyter_console-6.2.0      |             py_0          26 KB
#     jupyter_core-4.7.0         |   py37hecd8cb5_0          68 KB
#     jupyterlab-2.2.6           |             py_0         3.4 MB
#     jupyterlab_pygments-0.1.2  |             py_0           8 KB
#     jupyterlab_server-1.2.0    |             py_0          25 KB
#     jupyterlab_widgets-1.0.0   |     pyhd3eb1b0_1         109 KB
#     keyring-21.8.0             |   py37hecd8cb5_0          53 KB
#     kiwisolver-1.3.0           |   py37h23ab428_0          52 KB
#     krb5-1.18.2                |       h75d18d8_0         1.1 MB
#     lazy-object-proxy-1.4.3    |   py37h9ed2024_2          29 KB
#     lcms2-2.11                 |       h92f6f08_0         278 KB
#     libarchive-3.4.2           |       haa3ed63_0         711 KB
#     libcurl-7.71.1             |       h8a08a2b_1         289 KB
#     libcxx-10.0.0              |                1         760 KB
#     libedit-3.1.20191231       |       h1de35cc_1          96 KB
#     libffi-3.3                 |       hb1e8313_2          44 KB
#     libiconv-1.16              |       h1de35cc_0         693 KB
#     liblief-0.10.1             |       h0a44026_0         1.5 MB
#     libllvm10-10.0.1           |       h76017ad_5        16.4 MB
#     libllvm9-9.0.1             |       h21ff451_1        15.4 MB
#     libsodium-1.0.18           |       h1de35cc_0         236 KB
#     libtiff-4.1.0              |       hcb84e12_1         405 KB
#     libxml2-2.9.10             |       h7cdb67c_3         1.1 MB
#     libxslt-1.1.34             |       h83b36ba_0         395 KB
#     llvm-openmp-10.0.0         |       h28b9765_0         236 KB
#     llvmlite-0.34.0            |   py37h739e7dc_4         248 KB
#     lxml-4.6.2                 |   py37h26b266a_0         1.1 MB
#     lz4-c-1.9.2                |       h79c402e_3         130 KB
#     lzo-2.10                   |       haf1e3a3_2         141 KB
#     mkl-service-2.3.0          |   py37h9ed2024_0          40 KB
#     mkl_fft-1.2.0              |   py37hc64f4ea_0         141 KB
#     mkl_random-1.1.1           |   py37h959d312_0         284 KB
#     mock-4.0.3                 |     pyhd3eb1b0_0          29 KB
#     more-itertools-8.6.0       |     pyhd3eb1b0_0          40 KB
#     mpfr-4.0.2                 |       h9066e36_1         433 KB
#     msgpack-python-1.0.1       |   py37hf7b0b51_0          74 KB
#     nbclient-0.5.1             |             py_0          58 KB
#     nbconvert-6.0.7            |           py37_0         484 KB
#     nbformat-5.1.2             |     pyhd3eb1b0_1          68 KB
#     ncurses-6.2                |       h0a44026_1         749 KB
#     nest-asyncio-1.4.3         |     pyhd3eb1b0_0          11 KB
#     networkx-2.5               |             py_0         1.1 MB
#     nltk-3.5                   |             py_0         976 KB
#     nose-1.3.7                 |  pyhd3eb1b0_1006         128 KB
#     notebook-6.1.6             |   py37hecd8cb5_0         4.1 MB
#     numba-0.51.2               |   py37h959d312_1         3.1 MB
#     numexpr-2.7.2              |   py37h16bde0e_0         119 KB
#     numpy-1.19.2               |   py37h456fd55_0          21 KB
#     numpy-base-1.19.2          |   py37hcfb5961_0         4.0 MB
#     openpyxl-3.0.6             |     pyhd3eb1b0_0         159 KB
#     packaging-20.8             |     pyhd3eb1b0_0          36 KB
#     pandas-1.2.0               |   py37hb2f4e1b_0         8.1 MB
#     pandoc-2.11                |       h0dc7051_0        10.8 MB
#     pandocfilters-1.4.3        |   py37hecd8cb5_1          14 KB
#     path-15.0.1                |   py37hecd8cb5_0          37 KB
#     path.py-12.5.0             |                0           4 KB
#     pathlib2-2.3.5             |   py37hecd8cb5_2          38 KB
#     pcre-8.44                  |       hb1e8313_0         185 KB
#     pexpect-4.8.0              |     pyhd3eb1b0_3          53 KB
#     pickleshare-0.7.5          |  pyhd3eb1b0_1003          13 KB
#     pillow-8.1.0               |   py37h5270095_0         587 KB
#     pip-20.3.3                 |   py37hecd8cb5_0         1.7 MB
#     pkginfo-1.6.1              |   py37hecd8cb5_0          42 KB
#     prometheus_client-0.9.0    |     pyhd3eb1b0_0          45 KB
#     prompt-toolkit-3.0.8       |             py_0         248 KB
#     prompt_toolkit-3.0.8       |                0          12 KB
#     psutil-5.7.2               |   py37haf1e3a3_0         337 KB
#     ptyprocess-0.7.0           |     pyhd3eb1b0_2          17 KB
#     py-1.10.0                  |     pyhd3eb1b0_0          76 KB
#     py-lief-0.10.1             |   py37haf313ee_0        1022 KB
#     pycodestyle-2.6.0          |             py_0          43 KB
#     pycosat-0.6.3              |   py37h9ed2024_0          86 KB
#     pycparser-2.20             |             py_2          94 KB
#     pycrypto-2.6.1             |  py37haf1e3a3_10         365 KB
#     pycurl-7.43.0.6            |   py37hddc9c9b_0          65 KB
#     pydocstyle-5.1.1           |             py_0          38 KB
#     pyerfa-1.7.1.1             |   py37h9ed2024_1         297 KB
#     pyflakes-2.2.0             |             py_0          61 KB
#     pygments-2.7.4             |     pyhd3eb1b0_0         676 KB
#     pylint-2.6.0               |           py37_0         436 KB
#     pyopenssl-20.0.1           |     pyhd3eb1b0_1          49 KB
#     pyparsing-2.4.7            |             py_0          65 KB
#     pyrsistent-0.17.3          |   py37haf1e3a3_0          87 KB
#     pysocks-1.7.1              |   py37hecd8cb5_0          31 KB
#     pytest-6.2.1               |   py37hecd8cb5_0         420 KB
#     python-jsonrpc-server-0.4.0|             py_0          12 KB
#     python-libarchive-c-2.9    |             py_0          46 KB
#     pytz-2020.5                |     pyhd3eb1b0_0         182 KB
#     pywavelets-1.1.1           |   py37haf1e3a3_2         3.4 MB
#     pyyaml-5.3.1               |   py37haf1e3a3_1         165 KB
#     pyzmq-20.0.0               |   py37h23ab428_1         397 KB
#     qdarkstyle-2.8.1           |             py_0         176 KB
#     qtawesome-1.0.1            |             py_0         757 KB
#     qtconsole-4.7.7            |             py_0          96 KB
#     regex-2020.11.13           |   py37h9ed2024_0         307 KB
#     ripgrep-12.1.1             |                0         1.3 MB
#     rope-0.18.0                |             py_0         126 KB
#     rtree-0.9.4                |           py37_1          47 KB
#     ruamel_yaml-0.15.87        |   py37haf1e3a3_1         235 KB
#     scikit-learn-0.23.2        |   py37h959d312_0         4.7 MB
#     scipy-1.5.2                |   py37h912ce22_0        13.2 MB
#     send2trash-1.5.0           |     pyhd3eb1b0_1          14 KB
#     setuptools-51.1.2          |   py37hecd8cb5_4         728 KB
#     singledispatch-3.4.0.3     |          py_1001          12 KB
#     six-1.15.0                 |   py37hecd8cb5_0          27 KB
#     snappy-1.1.8               |       hb1e8313_0          54 KB
#     sortedcollections-1.2.3    |     pyhd3eb1b0_0          11 KB
#     sortedcontainers-2.3.0     |     pyhd3eb1b0_0          26 KB
#     soupsieve-2.1              |     pyhd3eb1b0_0          31 KB
#     sphinxcontrib-applehelp-1.0.2|             py_0          27 KB
#     sphinxcontrib-devhelp-1.0.2|             py_0          22 KB
#     sphinxcontrib-htmlhelp-1.0.3|             py_0          27 KB
#     sphinxcontrib-qthelp-1.0.3 |             py_0          25 KB
#     sphinxcontrib-serializinghtml-1.1.4|             py_0          24 KB
#     sphinxcontrib-websupport-1.2.4|             py_0          34 KB
#     sqlalchemy-1.3.21          |   py37h9ed2024_0         1.5 MB
#     sqlite-3.33.0              |       hffcf06c_0         1.3 MB
#     sympy-1.7.1                |   py37hecd8cb5_0         8.8 MB
#     tbb-2020.3                 |       h879752b_0         147 KB
#     tblib-1.7.0                |             py_0          16 KB
#     terminado-0.9.2            |   py37hecd8cb5_0          25 KB
#     threadpoolctl-2.1.0        |     pyh5ca1d4c_0          17 KB
#     tk-8.6.10                  |       hb0a8c7a_0         3.0 MB
#     toml-0.10.1                |             py_0          20 KB
#     toolz-0.11.1               |             py_0          48 KB
#     tornado-6.1                |   py37h9ed2024_0         588 KB
#     traitlets-5.0.5            |             py_0          83 KB
#     typed-ast-1.4.2            |   py37h9ed2024_1         183 KB
#     typing_extensions-3.7.4.3  |             py_0          28 KB
#     ujson-4.0.1                |   py37hb1e8313_0          46 KB
#     unixodbc-2.3.9             |       haf1e3a3_0         251 KB
#     urllib3-1.26.2             |     pyhd3eb1b0_0         105 KB
#     watchdog-0.10.4            |   py37h9ed2024_0          97 KB
#     wcwidth-0.2.5              |             py_0          29 KB
#     werkzeug-1.0.1             |             py_0         240 KB
#     wheel-0.36.2               |     pyhd3eb1b0_0          33 KB
#     wrapt-1.11.2               |   py37h9ed2024_0          44 KB
#     wurlitzer-2.0.1            |           py37_0          14 KB
#     xlrd-2.0.1                 |     pyhd3eb1b0_0          90 KB
#     xlsxwriter-1.3.7           |             py_0         108 KB
#     xlwings-0.21.4             |   py37hecd8cb5_0         442 KB
#     xz-5.2.5                   |       h1de35cc_0         240 KB
#     yaml-0.2.5                 |       haf1e3a3_0          72 KB
#     yapf-0.30.0                |             py_0         127 KB
#     zeromq-4.3.3               |       hb1e8313_3         414 KB
#     zict-2.0.0                 |             py_0          13 KB
#     zipp-3.4.0                 |     pyhd3eb1b0_0          15 KB
#     zope-1.0                   |           py37_1           4 KB
#     zope.event-4.5.0           |           py37_0         209 KB
#     zope.interface-5.2.0       |   py37h9ed2024_0         278 KB
#     zstd-1.4.5                 |       h41d2c2f_0         442 KB
#     ------------------------------------------------------------
#                                            Total:       179.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/osx-64::_anaconda_depends-2020.07-py37_0
#   argon2-cffi        pkgs/main/osx-64::argon2-cffi-20.1.0-py37haf1e3a3_1
#   async_generator    pkgs/main/osx-64::async_generator-1.10-py37h28b3542_0
#   brotlipy           pkgs/main/osx-64::brotlipy-0.7.0-py37h9ed2024_1003
#   importlib-metadata pkgs/main/noarch::importlib-metadata-2.0.0-py_1
#   iniconfig          pkgs/main/noarch::iniconfig-1.1.1-py_0
#   jupyterlab_pygmen~ pkgs/main/noarch::jupyterlab_pygments-0.1.2-py_0
#   jupyterlab_widgets pkgs/main/noarch::jupyterlab_widgets-1.0.0-pyhd3eb1b0_1
#   lcms2              pkgs/main/osx-64::lcms2-2.11-h92f6f08_0
#   libllvm10          pkgs/main/osx-64::libllvm10-10.0.1-h76017ad_5
#   libllvm9           pkgs/main/osx-64::libllvm9-9.0.1-h21ff451_1
#   matplotlib-base    pkgs/main/osx-64::matplotlib-base-3.1.3-py37h9aa3819_0
#   nbclient           pkgs/main/noarch::nbclient-0.5.1-py_0
#   nest-asyncio       pkgs/main/noarch::nest-asyncio-1.4.3-pyhd3eb1b0_0
#   pandas             pkgs/main/osx-64::pandas-1.2.0-py37hb2f4e1b_0
#   prompt-toolkit     pkgs/main/noarch::prompt-toolkit-3.0.8-py_0
#   pyerfa             pkgs/main/osx-64::pyerfa-1.7.1.1-py37h9ed2024_1
#   regex              pkgs/main/osx-64::regex-2020.11.13-py37h9ed2024_0
#   requests           pkgs/main/noarch::requests-2.25.1-pyhd3eb1b0_0
#   seaborn            pkgs/main/noarch::seaborn-0.11.1-pyhd3eb1b0_0
#   threadpoolctl      pkgs/main/noarch::threadpoolctl-2.1.0-pyh5ca1d4c_0
#   toml               pkgs/main/noarch::toml-0.10.1-py_0
#   tqdm               pkgs/main/noarch::tqdm-4.55.1-pyhd3eb1b0_0
#   typed-ast          pkgs/main/osx-64::typed-ast-1.4.2-py37h9ed2024_1
#   typing_extensions  pkgs/main/noarch::typing_extensions-3.7.4.3-py_0
#   zope               pkgs/main/osx-64::zope-1.0-py37_1
#   zope.event         pkgs/main/osx-64::zope.event-4.5.0-py37_0
#   zope.interface     pkgs/main/osx-64::zope.interface-5.2.0-py37h9ed2024_0
#
# The following packages will be UPDATED:
#
#   appnope                                      0.1.0-py37_0 --> 0.1.2-py37hecd8cb5_1001
#   appscript                            1.1.0-py37h1de35cc_0 --> 1.1.1-py37haf1e3a3_0
#   asn1crypto         pkgs/main/osx-64::asn1crypto-1.3.0-py~ --> pkgs/main/noarch::asn1crypto-1.4.0-py_0
#   astroid                                      2.3.3-py37_0 --> 2.4.2-py37_0
#   astropy                                4.0-py37h1de35cc_0 --> 4.2-py37h9ed2024_0
#   atomicwrites       pkgs/main/osx-64::atomicwrites-1.3.0-~ --> pkgs/main/noarch::atomicwrites-1.4.0-py_0
#   attrs                                         19.3.0-py_0 --> 20.3.0-pyhd3eb1b0_0
#   autopep8                                       1.4.4-py_0 --> 1.5.4-py_0
#   babel                                          2.8.0-py_0 --> 2.9.0-pyhd3eb1b0_0
#   backcall           pkgs/main/osx-64::backcall-0.1.0-py37~ --> pkgs/main/noarch::backcall-0.2.0-py_0
#   backports.shutil_~ pkgs/main/osx-64::backports.shutil_ge~ --> pkgs/main/noarch::backports.shutil_get_terminal_size-1.0.0-pyhd3eb1b0_3
#   beautifulsoup4     pkgs/main/osx-64::beautifulsoup4-4.8.~ --> pkgs/main/noarch::beautifulsoup4-4.9.3-pyhb0f4dca_0
#   bitarray                             1.2.1-py37h1de35cc_0 --> 1.6.1-py37h9ed2024_0
#   bleach              pkgs/main/osx-64::bleach-3.1.0-py37_0 --> pkgs/main/noarch::bleach-3.2.1-py_0
#   blosc                                   1.16.3-hd9629dc_0 --> 1.20.1-hab81aa3_0
#   bokeh                                        1.4.0-py37_0 --> 2.2.3-py37_0
#   bottleneck                           1.3.2-py37h776bbcc_0 --> 1.3.2-py37hf1fa96c_1
#   ca-certificates                                2020.1.1-0 --> 2020.12.8-hecd8cb5_0
#   certifi                                 2019.11.28-py37_0 --> 2020.12.5-py37hecd8cb5_0
#   cffi                                1.14.0-py37hb5b8e2f_0 --> 1.14.4-py37h2125817_0
#   chardet                                   3.0.4-py37_1003 --> 4.0.0-py37hecd8cb5_1003
#   click                  pkgs/main/osx-64::click-7.0-py37_0 --> pkgs/main/noarch::click-7.1.2-py_0
#   cloudpickle                                    1.3.0-py_0 --> 1.6.0-py_0
#   colorama                                       0.4.3-py_0 --> 0.4.4-pyhd3eb1b0_0
#   cryptography                           2.8-py37ha12b0ac_0 --> 3.3.1-py37hbcfaee0_0
#   curl                                    7.68.0-ha441bb4_0 --> 7.71.1-hb0a8c7a_1
#   cython                             0.29.15-py37h0a44026_0 --> 0.29.21-py37h23ab428_0
#   cytoolz                             0.10.1-py37h1de35cc_0 --> 0.11.0-py37haf1e3a3_0
#   dbus                                   1.13.12-h90a0687_0 --> 1.13.18-h18a8e69_0
#   decorator                                      4.4.1-py_0 --> 4.4.2-py_0
#   diff-match-patch                            20181111-py_0 --> 20200713-py_0
#   distributed                                 2.11.0-py37_0 --> 2.30.1-py37hecd8cb5_0
#   docutils                                      0.16-py37_0 --> 0.16-py37_1
#   et_xmlfile         pkgs/main/osx-64::et_xmlfile-1.0.1-py~ --> pkgs/main/noarch::et_xmlfile-1.0.1-py_1001
#   expat                                    2.2.6-h0a44026_0 --> 2.2.10-hb1e8313_2
#   flake8              pkgs/main/osx-64::flake8-3.7.9-py37_0 --> pkgs/main/noarch::flake8-3.8.4-py_0
#   flask                                          1.1.1-py_0 --> 1.1.2-py_0
#   freetype                                 2.9.1-hb4e5f40_0 --> 2.10.4-ha233b18_0
#   fsspec                                         0.6.2-py_0 --> 0.8.3-py_0
#   future                                      0.18.2-py37_0 --> 0.18.2-py37_1
#   gevent                               1.4.0-py37h1de35cc_0 --> 20.12.1-py37h9ed2024_1
#   glib                                    2.63.1-hd977a24_0 --> 2.66.1-h9bbe63b_0
#   greenlet                            0.4.15-py37h1de35cc_0 --> 0.4.17-py37haf1e3a3_0
#   html5lib           pkgs/main/osx-64::html5lib-1.0.1-py37~ --> pkgs/main/noarch::html5lib-1.1-py_0
#   icu                                       58.2-h4b95b61_1 --> 58.2-h0a44026_3
#   idna                    pkgs/main/osx-64::idna-2.8-py37_0 --> pkgs/main/noarch::idna-2.10-py_0
#   imageio            pkgs/main/osx-64::imageio-2.6.1-py37_0 --> pkgs/main/noarch::imageio-2.9.0-py_0
#   importlib_metadata pkgs/main/osx-64::importlib_metadata-~ --> pkgs/main/noarch::importlib_metadata-2.0.0-1
#   intervaltree                                   3.0.2-py_0 --> 3.1.0-py_0
#   ipykernel                            5.1.4-py37h39e3cac_0 --> 5.3.4-py37h5ca1d4c_0
#   ipython                             7.12.0-py37h5ca1d4c_0 --> 7.19.0-py37h01d92e1_1
#   ipython_genutils   pkgs/main/osx-64::ipython_genutils-0.~ --> pkgs/main/noarch::ipython_genutils-0.2.0-pyhd3eb1b0_1
#   ipywidgets                                     7.5.1-py_0 --> 7.6.3-pyhd3eb1b0_1
#   isort               pkgs/main/osx-64::isort-4.3.21-py37_0 --> pkgs/main/noarch::isort-5.6.4-py_0
#   jinja2                                        2.11.1-py_0 --> 2.11.2-py_0
#   joblib                                        0.14.1-py_0 --> 1.0.0-pyhd3eb1b0_0
#   json5                                          0.9.1-py_0 --> 0.9.5-py_0
#   jsonschema         pkgs/main/osx-64::jsonschema-3.2.0-py~ --> pkgs/main/noarch::jsonschema-3.2.0-py_2
#   jupyter_client     pkgs/main/osx-64::jupyter_client-5.3.~ --> pkgs/main/noarch::jupyter_client-6.1.7-py_0
#   jupyter_console                                6.1.0-py_0 --> 6.2.0-py_0
#   jupyter_core                                 4.6.1-py37_0 --> 4.7.0-py37hecd8cb5_0
#   jupyterlab                             1.2.6-pyhf63ae98_0 --> 2.2.6-py_0
#   jupyterlab_server                              1.0.6-py_0 --> 1.2.0-py_0
#   keyring                                     21.1.0-py37_0 --> 21.8.0-py37hecd8cb5_0
#   kiwisolver                           1.1.0-py37h0a44026_0 --> 1.3.0-py37h23ab428_0
#   krb5                                    1.17.1-hddcf347_0 --> 1.18.2-h75d18d8_0
#   lazy-object-proxy                    1.4.3-py37h1de35cc_0 --> 1.4.3-py37h9ed2024_2
#   libarchive                               3.3.3-h786848e_5 --> 3.4.2-haa3ed63_0
#   libcurl                                 7.68.0-h051b688_0 --> 7.71.1-h8a08a2b_1
#   libcxx                                   4.0.1-hcfea43d_1 --> 10.0.0-1
#   libedit                           3.1.20181209-hb402a30_0 --> 3.1.20191231-h1de35cc_1
#   libffi                                   3.2.1-h475c297_4 --> 3.3-hb1e8313_2
#   libiconv                                  1.15-hdd342a3_7 --> 1.16-h1de35cc_0
#   liblief                                  0.9.0-h2a1bed3_2 --> 0.10.1-h0a44026_0
#   libsodium                               1.0.16-h3efe00b_0 --> 1.0.18-h1de35cc_0
#   libtiff                                  4.1.0-hcb84e12_0 --> 4.1.0-hcb84e12_1
#   libxml2                                  2.9.9-hf6e021a_1 --> 2.9.10-h7cdb67c_3
#   libxslt                                 1.1.33-h33a18ac_0 --> 1.1.34-h83b36ba_0
#   llvm-openmp                              4.0.1-hcfea43d_1 --> 10.0.0-h28b9765_0
#   llvmlite                            0.31.0-py37h1341992_0 --> 0.34.0-py37h739e7dc_4
#   lxml                                 4.5.0-py37hef8c89e_0 --> 4.6.2-py37h26b266a_0
#   lz4-c                                  1.8.1.2-h1de35cc_0 --> 1.9.2-h79c402e_3
#   mkl_fft                             1.0.15-py37h5e564d8_0 --> 1.2.0-py37hc64f4ea_0
#   mkl_random                           1.1.0-py37ha771720_0 --> 1.1.1-py37h959d312_0
#   mock                                           4.0.1-py_0 --> 4.0.3-pyhd3eb1b0_0
#   more-itertools                                 8.2.0-py_0 --> 8.6.0-pyhd3eb1b0_0
#   mpfr                                     4.0.1-h3018a27_3 --> 4.0.2-h9066e36_1
#   msgpack-python                       0.6.1-py37h04f5b5a_1 --> 1.0.1-py37hf7b0b51_0
#   nbconvert                                    5.6.1-py37_0 --> 6.0.7-py37_0
#   nbformat                                       5.0.4-py_0 --> 5.1.2-pyhd3eb1b0_1
#   ncurses                                    6.2-h0a44026_0 --> 6.2-h0a44026_1
#   networkx                                         2.4-py_0 --> 2.5-py_0
#   nltk                  pkgs/main/osx-64::nltk-3.4.5-py37_0 --> pkgs/main/noarch::nltk-3.5-py_0
#   nose                  pkgs/main/osx-64::nose-1.3.7-py37_2 --> pkgs/main/noarch::nose-1.3.7-pyhd3eb1b0_1006
#   notebook                                     6.0.3-py37_0 --> 6.1.6-py37hecd8cb5_0
#   numba                               0.48.0-py37h6c726b0_0 --> 0.51.2-py37h959d312_1
#   numexpr                              2.7.1-py37hce01a72_0 --> 2.7.2-py37h16bde0e_0
#   numpy                               1.18.1-py37h7241aed_0 --> 1.19.2-py37h456fd55_0
#   numpy-base                          1.18.1-py37h6575580_1 --> 1.19.2-py37hcfb5961_0
#   openpyxl                                       3.0.3-py_0 --> 3.0.6-pyhd3eb1b0_0
#   openssl                                 1.1.1d-h1de35cc_4 --> 1.1.1i-h9ed2024_0
#   packaging                                       20.1-py_0 --> 20.8-pyhd3eb1b0_0
#   pandoc                                          2.2.3.2-0 --> 2.11-h0dc7051_0
#   pandocfilters                                1.4.2-py37_1 --> 1.4.3-py37hecd8cb5_1
#   path                                        13.1.0-py37_0 --> 15.0.1-py37hecd8cb5_0
#   path.py                                          12.4.0-0 --> 12.5.0-0
#   pathlib2                                     2.3.5-py37_0 --> 2.3.5-py37hecd8cb5_2
#   pcre                                      8.43-h0a44026_0 --> 8.44-hb1e8313_0
#   pexpect            pkgs/main/osx-64::pexpect-4.8.0-py37_0 --> pkgs/main/noarch::pexpect-4.8.0-pyhd3eb1b0_3
#   pickleshare        pkgs/main/osx-64::pickleshare-0.7.5-p~ --> pkgs/main/noarch::pickleshare-0.7.5-pyhd3eb1b0_1003
#   pillow                               7.0.0-py37h4655f20_0 --> 8.1.0-py37h5270095_0
#   pip                                         20.0.2-py37_1 --> 20.3.3-py37hecd8cb5_0
#   pkginfo                                    1.5.0.1-py37_0 --> 1.6.1-py37hecd8cb5_0
#   prometheus_client                              0.7.1-py_0 --> 0.9.0-pyhd3eb1b0_0
#   prompt_toolkit                                 3.0.3-py_0 --> 3.0.8-0
#   psutil                               5.6.7-py37h1de35cc_0 --> 5.7.2-py37haf1e3a3_0
#   ptyprocess         pkgs/main/osx-64::ptyprocess-0.6.0-py~ --> pkgs/main/noarch::ptyprocess-0.7.0-pyhd3eb1b0_2
#   py                                             1.8.1-py_0 --> 1.10.0-pyhd3eb1b0_0
#   py-lief                              0.9.0-py37h1413db1_2 --> 0.10.1-py37haf313ee_0
#   pycodestyle        pkgs/main/osx-64::pycodestyle-2.5.0-p~ --> pkgs/main/noarch::pycodestyle-2.6.0-py_0
#   pycparser          pkgs/main/osx-64::pycparser-2.19-py37~ --> pkgs/main/noarch::pycparser-2.20-py_2
#   pycrypto                             2.6.1-py37h1de35cc_9 --> 2.6.1-py37haf1e3a3_10
#   pycurl                            7.43.0.5-py37ha12b0ac_0 --> 7.43.0.6-py37hddc9c9b_0
#   pydocstyle                                     4.0.1-py_0 --> 5.1.1-py_0
#   pyflakes           pkgs/main/osx-64::pyflakes-2.1.1-py37~ --> pkgs/main/noarch::pyflakes-2.2.0-py_0
#   pygments                                       2.5.2-py_0 --> 2.7.4-pyhd3eb1b0_0
#   pylint                                       2.4.4-py37_0 --> 2.6.0-py37_0
#   pyopenssl          pkgs/main/osx-64::pyopenssl-19.1.0-py~ --> pkgs/main/noarch::pyopenssl-20.0.1-pyhd3eb1b0_1
#   pyparsing                                      2.4.6-py_0 --> 2.4.7-py_0
#   pyrsistent                          0.15.7-py37h1de35cc_0 --> 0.17.3-py37haf1e3a3_0
#   pytest                                       5.3.5-py37_0 --> 6.2.1-py37hecd8cb5_0
#   python-jsonrpc-se~                             0.3.4-py_0 --> 0.4.0-py_0
#   python-libarchive~ pkgs/main/osx-64::python-libarchive-c~ --> pkgs/main/noarch::python-libarchive-c-2.9-py_0
#   pytz                                          2019.3-py_0 --> 2020.5-pyhd3eb1b0_0
#   pywavelets                           1.1.1-py37h1de35cc_0 --> 1.1.1-py37haf1e3a3_2
#   pyyaml                                 5.3-py37h1de35cc_0 --> 5.3.1-py37haf1e3a3_1
#   pyzmq                               18.1.1-py37h0a44026_0 --> 20.0.0-py37h23ab428_1
#   qdarkstyle                                       2.8-py_0 --> 2.8.1-py_0
#   qtawesome                                      0.6.1-py_0 --> 1.0.1-py_0
#   qtconsole                                      4.6.0-py_1 --> 4.7.7-py_0
#   ripgrep                                 11.0.2-he32d670_0 --> 12.1.1-0
#   rope                                          0.16.0-py_0 --> 0.18.0-py_0
#   rtree                                        0.9.3-py37_0 --> 0.9.4-py37_1
#   ruamel_yaml                        0.15.87-py37h1de35cc_0 --> 0.15.87-py37haf1e3a3_1
#   scikit-learn                        0.22.1-py37h27c97d8_0 --> 0.23.2-py37h959d312_0
#   scipy                                1.4.1-py37h9fa6033_0 --> 1.5.2-py37h912ce22_0
#   send2trash         pkgs/main/osx-64::send2trash-1.5.0-py~ --> pkgs/main/noarch::send2trash-1.5.0-pyhd3eb1b0_1
#   setuptools                                  46.0.0-py37_0 --> 51.1.2-py37hecd8cb5_4
#   singledispatch     pkgs/main/osx-64::singledispatch-3.4.~ --> pkgs/main/noarch::singledispatch-3.4.0.3-py_1001
#   six                                         1.14.0-py37_0 --> 1.15.0-py37hecd8cb5_0
#   snappy                                   1.1.7-he62c110_3 --> 1.1.8-hb1e8313_0
#   sortedcollections  pkgs/main/osx-64::sortedcollections-1~ --> pkgs/main/noarch::sortedcollections-1.2.3-pyhd3eb1b0_0
#   sortedcontainers   pkgs/main/osx-64::sortedcontainers-2.~ --> pkgs/main/noarch::sortedcontainers-2.3.0-pyhd3eb1b0_0
#   soupsieve          pkgs/main/osx-64::soupsieve-1.9.5-py3~ --> pkgs/main/noarch::soupsieve-2.1-pyhd3eb1b0_0
#   sphinxcontrib-app~                             1.0.1-py_0 --> 1.0.2-py_0
#   sphinxcontrib-dev~                             1.0.1-py_0 --> 1.0.2-py_0
#   sphinxcontrib-htm~                             1.0.2-py_0 --> 1.0.3-py_0
#   sphinxcontrib-qth~                             1.0.2-py_0 --> 1.0.3-py_0
#   sphinxcontrib-ser~                             1.1.3-py_0 --> 1.1.4-py_0
#   sphinxcontrib-web~                             1.2.0-py_0 --> 1.2.4-py_0
#   sqlalchemy                          1.3.13-py37h1de35cc_0 --> 1.3.21-py37h9ed2024_0
#   sqlite                                  3.31.1-ha441bb4_0 --> 3.33.0-hffcf06c_0
#   sympy                                        1.5.1-py37_0 --> 1.7.1-py37hecd8cb5_0
#   tbb                                     2020.0-h04f5b5a_0 --> 2020.3-h879752b_0
#   tblib                                          1.6.0-py_0 --> 1.7.0-py_0
#   terminado                                    0.8.3-py37_0 --> 0.9.2-py37hecd8cb5_0
#   tk                                       8.6.8-ha441bb4_0 --> 8.6.10-hb0a8c7a_0
#   toolz                                         0.10.0-py_0 --> 0.11.1-py_0
#   tornado                              6.0.3-py37h1de35cc_3 --> 6.1-py37h9ed2024_0
#   traitlets          pkgs/main/osx-64::traitlets-4.3.3-py3~ --> pkgs/main/noarch::traitlets-5.0.5-py_0
#   ujson                                 1.35-py37h1de35cc_0 --> 4.0.1-py37hb1e8313_0
#   unixodbc                                 2.3.7-h1de35cc_0 --> 2.3.9-haf1e3a3_0
#   urllib3            pkgs/main/osx-64::urllib3-1.25.8-py37~ --> pkgs/main/noarch::urllib3-1.26.2-pyhd3eb1b0_0
#   watchdog                            0.10.2-py37h1de35cc_0 --> 0.10.4-py37h9ed2024_0
#   wcwidth                                        0.1.8-py_0 --> 0.2.5-py_0
#   werkzeug                                       1.0.0-py_0 --> 1.0.1-py_0
#   wheel               pkgs/main/osx-64::wheel-0.34.2-py37_0 --> pkgs/main/noarch::wheel-0.36.2-pyhd3eb1b0_0
#   wurlitzer                                    2.0.0-py37_0 --> 2.0.1-py37_0
#   xlrd                  pkgs/main/osx-64::xlrd-1.2.0-py37_0 --> pkgs/main/noarch::xlrd-2.0.1-pyhd3eb1b0_0
#   xlsxwriter                                     1.2.7-py_0 --> 1.3.7-py_0
#   xlwings                                     0.17.1-py37_0 --> 0.21.4-py37hecd8cb5_0
#   xz                                       5.2.4-h1de35cc_4 --> 5.2.5-h1de35cc_0
#   yaml                                     0.1.7-hc338f04_2 --> 0.2.5-haf1e3a3_0
#   yapf                                          0.28.0-py_0 --> 0.30.0-py_0
#   zeromq                                   4.3.1-h0a44026_3 --> 4.3.3-hb1e8313_3
#   zict                                           1.0.0-py_0 --> 2.0.0-py_0
#   zipp                                           2.2.0-py_0 --> 3.4.0-pyhd3eb1b0_0
#   zstd                                     1.3.7-h5bba6e5_0 --> 1.4.5-h41d2c2f_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2020.02-py37_0 --> custom-py37_1
#   backports                                        1.0-py_2 --> 1.0-pyhd3eb1b0_2
#   backports.functoo~                             1.6.1-py_0 --> 1.6.1-pyhd3eb1b0_0
#   gettext                               0.19.8.1-h15daf44_3 --> 0.19.8.1-hb0f4f8b_2
#   lzo                                       2.10-h362108e_2 --> 2.10-haf1e3a3_2
#   mkl-service                          2.3.0-py37hfbe908c_0 --> 2.3.0-py37h9ed2024_0
#   pycosat                              0.6.3-py37h1de35cc_0 --> 0.6.3-py37h9ed2024_0
#   pysocks                                      1.7.1-py37_0 --> 1.7.1-py37hecd8cb5_0
#   wrapt                               1.11.2-py37h1de35cc_0 --> 1.11.2-py37h9ed2024_0
#
#
#
# Downloading and Extracting Packages
# json5-0.9.5          | 22 KB     | ##################################### | 100%
# xlwings-0.21.4       | 442 KB    | ##################################### | 100%
# networkx-2.5         | 1.1 MB    | ##################################### | 100%
# asn1crypto-1.4.0     | 80 KB     | ##################################### | 100%
# numba-0.51.2         | 3.1 MB    | ##################################### | 100%
# wcwidth-0.2.5        | 29 KB     | ##################################### | 100%
# traitlets-5.0.5      | 83 KB     | ##################################### | 100%
# greenlet-0.4.17      | 20 KB     | ##################################### | 100%
# zope.interface-5.2.0 | 278 KB    | ##################################### | 100%
# scipy-1.5.2          | 13.2 MB   | ##################################### | 100%
# bitarray-1.6.1       | 87 KB     | ##################################### | 100%
# unixodbc-2.3.9       | 251 KB    | ##################################### | 100%
# pickleshare-0.7.5    | 13 KB     | ##################################### | 100%
# pillow-8.1.0         | 587 KB    | ##################################### | 100%
# jupyter_client-6.1.7 | 77 KB     | ##################################### | 100%
# qtconsole-4.7.7      | 96 KB     | ##################################### | 100%
# backports.shutil_get | 10 KB     | ##################################### | 100%
# libcurl-7.71.1       | 289 KB    | ##################################### | 100%
# pyparsing-2.4.7      | 65 KB     | ##################################### | 100%
# ipython-7.19.0       | 1004 KB   | ##################################### | 100%
# ipykernel-5.3.4      | 182 KB    | ##################################### | 100%
# sortedcontainers-2.3 | 26 KB     | ##################################### | 100%
# backports-1.0        | 210 KB    | ##################################### | 100%
# mpfr-4.0.2           | 433 KB    | ##################################### | 100%
# iniconfig-1.1.1      | 9 KB      | ##################################### | 100%
# sqlalchemy-1.3.21    | 1.5 MB    | ##################################### | 100%
# toml-0.10.1          | 20 KB     | ##################################### | 100%
# libxml2-2.9.10       | 1.1 MB    | ##################################### | 100%
# diff-match-patch-202 | 36 KB     | ##################################### | 100%
# path.py-12.5.0       | 4 KB      | ##################################### | 100%
# nose-1.3.7           | 128 KB    | ##################################### | 100%
# jupyterlab-2.2.6     | 3.4 MB    | ##################################### | 100%
# jupyterlab_server-1. | 25 KB     | ##################################### | 100%
# wheel-0.36.2         | 33 KB     | ##################################### | 100%
# pkginfo-1.6.1        | 42 KB     | ##################################### | 100%
# backports.functools_ | 12 KB     | ##################################### | 100%
# distributed-2.30.1   | 1010 KB   | ##################################### | 100%
# terminado-0.9.2      | 25 KB     | ##################################### | 100%
# pytest-6.2.1         | 420 KB    | ##################################### | 100%
# jinja2-2.11.2        | 103 KB    | ##################################### | 100%
# docutils-0.16        | 667 KB    | ##################################### | 100%
# isort-5.6.4          | 78 KB     | ##################################### | 100%
# python-libarchive-c- | 46 KB     | ##################################### | 100%
# ripgrep-12.1.1       | 1.3 MB    | ##################################### | 100%
# lcms2-2.11           | 278 KB    | ##################################### | 100%
# pysocks-1.7.1        | 31 KB     | ##################################### | 100%
# flask-1.1.2          | 78 KB     | ##################################### | 100%
# gevent-20.12.1       | 1.5 MB    | ##################################### | 100%
# scikit-learn-0.23.2  | 4.7 MB    | ##################################### | 100%
# astropy-4.2          | 6.0 MB    | ##################################### | 100%
# lxml-4.6.2           | 1.1 MB    | ##################################### | 100%
# blosc-1.20.1         | 56 KB     | ##################################### | 100%
# kiwisolver-1.3.0     | 52 KB     | ##################################### | 100%
# openpyxl-3.0.6       | 159 KB    | ##################################### | 100%
# ncurses-6.2          | 749 KB    | ##################################### | 100%
# libedit-3.1.20191231 | 96 KB     | ##################################### | 100%
# zope.event-4.5.0     | 209 KB    | ##################################### | 100%
# tornado-6.1          | 588 KB    | ##################################### | 100%
# keyring-21.8.0       | 53 KB     | ##################################### | 100%
# async_generator-1.10 | 39 KB     | ##################################### | 100%
# snappy-1.1.8         | 54 KB     | ##################################### | 100%
# libiconv-1.16        | 693 KB    | ##################################### | 100%
# six-1.15.0           | 27 KB     | ##################################### | 100%
# urllib3-1.26.2       | 105 KB    | ##################################### | 100%
# python-jsonrpc-serve | 12 KB     | ##################################### | 100%
# nbclient-0.5.1       | 58 KB     | ##################################### | 100%
# imageio-2.9.0        | 3.0 MB    | ##################################### | 100%
# rope-0.18.0          | 126 KB    | ##################################### | 100%
# pyerfa-1.7.1.1       | 297 KB    | ##################################### | 100%
# toolz-0.11.1         | 48 KB     | ##################################### | 100%
# babel-2.9.0          | 5.5 MB    | ##################################### | 100%
# importlib-metadata-2 | 35 KB     | ##################################### | 100%
# chardet-4.0.0        | 194 KB    | ##################################### | 100%
# cython-0.29.21       | 1.8 MB    | ##################################### | 100%
# sqlite-3.33.0        | 1.3 MB    | ##################################### | 100%
# freetype-2.10.4      | 564 KB    | ##################################### | 100%
# sphinxcontrib-appleh | 27 KB     | ##################################### | 100%
# libcxx-10.0.0        | 760 KB    | ##################################### | 100%
# setuptools-51.1.2    | 728 KB    | ##################################### | 100%
# ujson-4.0.1          | 46 KB     | ##################################### | 100%
# jupyterlab_widgets-1 | 109 KB    | ##################################### | 100%
# pylint-2.6.0         | 436 KB    | ##################################### | 100%
# tk-8.6.10            | 3.0 MB    | ##################################### | 100%
# tblib-1.7.0          | 16 KB     | ##################################### | 100%
# singledispatch-3.4.0 | 12 KB     | ##################################### | 100%
# html5lib-1.1         | 93 KB     | ##################################### | 100%
# prompt-toolkit-3.0.8 | 248 KB    | ##################################### | 100%
# path-15.0.1          | 37 KB     | ##################################### | 100%
# msgpack-python-1.0.1 | 74 KB     | ##################################### | 100%
# regex-2020.11.13     | 307 KB    | ##################################### | 100%
# more-itertools-8.6.0 | 40 KB     | ##################################### | 100%
# lz4-c-1.9.2          | 130 KB    | ##################################### | 100%
# mkl-service-2.3.0    | 40 KB     | ##################################### | 100%
# mock-4.0.3           | 29 KB     | ##################################### | 100%
# pycodestyle-2.6.0    | 43 KB     | ##################################### | 100%
# notebook-6.1.6       | 4.1 MB    | ##################################### | 100%
# xz-5.2.5             | 240 KB    | ##################################### | 100%
# pyrsistent-0.17.3    | 87 KB     | ##################################### | 100%
# xlsxwriter-1.3.7     | 108 KB    | ##################################### | 100%
# zeromq-4.3.3         | 414 KB    | ##################################### | 100%
# numpy-1.19.2         | 21 KB     | ##################################### | 100%
# llvm-openmp-10.0.0   | 236 KB    | ##################################### | 100%
# prometheus_client-0. | 45 KB     | ##################################### | 100%
# packaging-20.8       | 36 KB     | ##################################### | 100%
# rtree-0.9.4          | 47 KB     | ##################################### | 100%
# pandocfilters-1.4.3  | 14 KB     | ##################################### | 100%
# wrapt-1.11.2         | 44 KB     | ##################################### | 100%
# libtiff-4.1.0        | 405 KB    | ##################################### | 100%
# pip-20.3.3           | 1.7 MB    | ##################################### | 100%
# libffi-3.3           | 44 KB     | ##################################### | 100%
# pandoc-2.11          | 10.8 MB   | ##################################### | 100%
# zict-2.0.0           | 13 KB     | ##################################### | 100%
# pcre-8.44            | 185 KB    | ##################################### | 100%
# et_xmlfile-1.0.1     | 12 KB     | ##################################### | 100%
# pydocstyle-5.1.1     | 38 KB     | ##################################### | 100%
# astroid-2.4.2        | 279 KB    | ##################################### | 100%
# libllvm10-10.0.1     | 16.4 MB   | ##################################### | 100%
# intervaltree-3.1.0   | 26 KB     | ##################################### | 100%
# nltk-3.5             | 976 KB    | ##################################### | 100%
# sphinxcontrib-htmlhe | 27 KB     | ##################################### | 100%
# gettext-0.19.8.1     | 2.7 MB    | ##################################### | 100%
# fsspec-0.8.3         | 72 KB     | ##################################### | 100%
# mkl_random-1.1.1     | 284 KB    | ##################################### | 100%
# sphinxcontrib-serial | 24 KB     | ##################################### | 100%
# py-1.10.0            | 76 KB     | ##################################### | 100%
# sortedcollections-1. | 11 KB     | ##################################### | 100%
# llvmlite-0.34.0      | 248 KB    | ##################################### | 100%
# jupyterlab_pygments- | 8 KB      | ##################################### | 100%
# pycurl-7.43.0.6      | 65 KB     | ##################################### | 100%
# wurlitzer-2.0.1      | 14 KB     | ##################################### | 100%
# ipython_genutils-0.2 | 27 KB     | ##################################### | 100%
# cytoolz-0.11.0       | 289 KB    | ##################################### | 100%
# lzo-2.10             | 141 KB    | ##################################### | 100%
# send2trash-1.5.0     | 14 KB     | ##################################### | 100%
# pathlib2-2.3.5       | 38 KB     | ##################################### | 100%
# jsonschema-3.2.0     | 47 KB     | ##################################### | 100%
# prompt_toolkit-3.0.8 | 12 KB     | ##################################### | 100%
# atomicwrites-1.4.0   | 11 KB     | ##################################### | 100%
# numexpr-2.7.2        | 119 KB    | ##################################### | 100%
# bleach-3.2.1         | 112 KB    | ##################################### | 100%
# libxslt-1.1.34       | 395 KB    | ##################################### | 100%
# attrs-20.3.0         | 43 KB     | ##################################### | 100%
# appnope-0.1.2        | 10 KB     | ##################################### | 100%
# pycrypto-2.6.1       | 365 KB    | ##################################### | 100%
# cryptography-3.3.1   | 554 KB    | ##################################### | 100%
# pygments-2.7.4       | 676 KB    | ##################################### | 100%
# bokeh-2.2.3          | 5.3 MB    | ##################################### | 100%
# pyzmq-20.0.0         | 397 KB    | ##################################### | 100%
# colorama-0.4.4       | 21 KB     | ##################################### | 100%
# typing_extensions-3. | 28 KB     | ##################################### | 100%
# pytz-2020.5          | 182 KB    | ##################################### | 100%
# watchdog-0.10.4      | 97 KB     | ##################################### | 100%
# pyopenssl-20.0.1     | 49 KB     | ##################################### | 100%
# jupyter_console-6.2. | 26 KB     | ##################################### | 100%
# future-0.18.2        | 630 KB    | ##################################### | 100%
# pandas-1.2.0         | 8.1 MB    | ##################################### | 100%
# pexpect-4.8.0        | 53 KB     | ##################################### | 100%
# pyyaml-5.3.1         | 165 KB    | ##################################### | 100%
# lazy-object-proxy-1. | 29 KB     | ##################################### | 100%
# liblief-0.10.1       | 1.5 MB    | ##################################### | 100%
# libarchive-3.4.2     | 711 KB    | ##################################### | 100%
# yaml-0.2.5           | 72 KB     | ##################################### | 100%
# _anaconda_depends-20 | 6 KB      | ##################################### | 100%
# ipywidgets-7.6.3     | 105 KB    | ##################################### | 100%
# decorator-4.4.2      | 14 KB     | ##################################### | 100%
# ruamel_yaml-0.15.87  | 235 KB    | ##################################### | 100%
# jupyter_core-4.7.0   | 68 KB     | ##################################### | 100%
# glib-2.66.1          | 2.7 MB    | ##################################### | 100%
# nbformat-5.1.2       | 68 KB     | ##################################### | 100%
# pycosat-0.6.3        | 86 KB     | ##################################### | 100%
# cloudpickle-1.6.0    | 30 KB     | ##################################### | 100%
# appscript-1.1.1      | 130 KB    | ##################################### | 100%
# py-lief-0.10.1       | 1022 KB   | ##################################### | 100%
# threadpoolctl-2.1.0  | 17 KB     | ##################################### | 100%
# tbb-2020.3           | 147 KB    | ##################################### | 100%
# dbus-1.13.18         | 445 KB    | ##################################### | 100%
# yapf-0.30.0          | 127 KB    | ##################################### | 100%
# xlrd-2.0.1           | 90 KB     | ##################################### | 100%
# numpy-base-1.19.2    | 4.0 MB    | ##################################### | 100%
# werkzeug-1.0.1       | 240 KB    | ##################################### | 100%
# sphinxcontrib-devhel | 22 KB     | ##################################### | 100%
# zope-1.0             | 4 KB      | ##################################### | 100%
# brotlipy-0.7.0       | 333 KB    | ##################################### | 100%
# nest-asyncio-1.4.3   | 11 KB     | ##################################### | 100%
# expat-2.2.10         | 110 KB    | ##################################### | 100%
# zipp-3.4.0           | 15 KB     | ##################################### | 100%
# libllvm9-9.0.1       | 15.4 MB   | ##################################### | 100%
# psutil-5.7.2         | 337 KB    | ##################################### | 100%
# pyflakes-2.2.0       | 61 KB     | ##################################### | 100%
# icu-58.2             | 10.1 MB   | ##################################### | 100%
# pycparser-2.20       | 94 KB     | ##################################### | 100%
# soupsieve-2.1        | 31 KB     | ##################################### | 100%
# ptyprocess-0.7.0     | 17 KB     | ##################################### | 100%
# sympy-1.7.1          | 8.8 MB    | ##################################### | 100%
# zstd-1.4.5           | 442 KB    | ##################################### | 100%
# qdarkstyle-2.8.1     | 176 KB    | ##################################### | 100%
# flake8-3.8.4         | 128 KB    | ##################################### | 100%
# curl-7.71.1          | 129 KB    | ##################################### | 100%
# argon2-cffi-20.1.0   | 44 KB     | ##################################### | 100%
# sphinxcontrib-websup | 34 KB     | ##################################### | 100%
# pywavelets-1.1.1     | 3.4 MB    | ##################################### | 100%
# beautifulsoup4-4.9.3 | 91 KB     | ##################################### | 100%
# typed-ast-1.4.2      | 183 KB    | ##################################### | 100%
# importlib_metadata-2 | 11 KB     | ##################################### | 100%
# bottleneck-1.3.2     | 107 KB    | ##################################### | 100%
# krb5-1.18.2          | 1.1 MB    | ##################################### | 100%
# backcall-0.2.0       | 15 KB     | ##################################### | 100%
# mkl_fft-1.2.0        | 141 KB    | ##################################### | 100%
# click-7.1.2          | 71 KB     | ##################################### | 100%
# libsodium-1.0.18     | 236 KB    | ##################################### | 100%
# cffi-1.14.4          | 214 KB    | ##################################### | 100%
# qtawesome-1.0.1      | 757 KB    | ##################################### | 100%
# idna-2.10            | 50 KB     | ##################################### | 100%
# nbconvert-6.0.7      | 484 KB    | ##################################### | 100%
# joblib-1.0.0         | 208 KB    | ##################################### | 100%
# sphinxcontrib-qthelp | 25 KB     | ##################################### | 100%
# autopep8-1.5.4       | 42 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: failed
#
# RemoveError: 'requests' is a dependency of conda and cannot be removed from
# conda's operating environment.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip3 install xgboost
# Out:
# Requirement already satisfied: xgboost in /Users/jinhou/opt/anaconda3/lib/python3.7/site-packages (1.3.2)
# Requirement already satisfied: scipy in /Users/jinhou/opt/anaconda3/lib/python3.7/site-packages (from xgboost) (1.4.1)
# Requirement already satisfied: numpy in /Users/jinhou/opt/anaconda3/lib/python3.7/site-packages (from xgboost) (1.18.1)

# %%
X, y = data.iloc[:,:-1],data.iloc[:,-1]

# %%
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)

# %%
xg_reg.fit(X_train,y_train)

preds = xg_reg.predict(X_test)
# Out:
# [20:25:40] WARNING: /Users/travis/build/dmlc/xgboost/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.

# %%
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 10.517005

# %%
params = {"objective":"reg:linear",'colsample_bytree': 0.3,'learning_rate': 0.1,
                'max_depth': 5, 'alpha': 10}

cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=3,
                    num_boost_round=50,early_stopping_rounds=10,metrics="rmse", as_pandas=True, seed=123)
# Out:
# [18:58:15] WARNING: /Users/travis/build/dmlc/xgboost/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:15] WARNING: /Users/travis/build/dmlc/xgboost/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:15] WARNING: /Users/travis/build/dmlc/xgboost/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.

# %%
cv_results.head()
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0        21.680257        0.025607       21.719121       0.019025
# 1        19.740500        0.072068       19.818879       0.061769
# 2        18.007202        0.119744       18.109862       0.129375
# 3        16.463925        0.115087       16.587235       0.182339
# 4        14.990313        0.112001       15.132976       0.166282

# %%
print((cv_results["test-rmse-mean"]).tail(1))
# Out:
# 49    3.862102
# Name: test-rmse-mean, dtype: float64

# %%
xg_reg = xgb.train(params=params, dtrain=data_dmatrix, num_boost_round=10)
# Out:
# [20:23:25] WARNING: /Users/travis/build/dmlc/xgboost/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.

# %%
pred = xg_reg.predict(X_test)

# %%
print(pred)
# Out:
# [ 9.107417  17.003168  23.554592  11.127839  18.847708  14.83594
#  17.920063   7.8613553 12.147531  18.064953  18.074614  14.411147
#  11.660895  15.656607  14.011221  14.031893  14.247164  23.057888
#  13.79595   11.450888  12.218057  15.310874  20.628437  23.554592
#  15.16144   13.139177  11.691522  15.382896  15.382896  11.007488
#  14.734173  18.862646   8.471523  15.349405  15.463427  19.77869
#  15.875313   9.95701   12.919248  23.60624   18.295853  12.589657
#  14.179869  21.97658   12.664099  16.489174  14.038502  15.660043
#  12.919248  14.453838  18.862646  17.252022  14.038502   7.9073224
#  14.332668  10.871179  10.826269   8.5319    19.534363   8.196141
#  12.403829  14.235118  10.42806   13.162136  14.247164  15.931118
#  16.565668   9.804545  14.915205  18.295853  13.15519   15.318869
#  12.919248  16.430174  11.854328  12.32626   11.756507  14.426096
#  18.501059   9.180772  19.065006   8.588221  15.463427  14.011221
#  12.898891  15.079189  11.267364  15.272911  14.247164  19.482258
#   9.210783  18.699503  13.79595   15.878302  19.92443   17.05043
#  11.450888  20.330242  16.072117  20.87532   14.714855  11.429612 ]

# %%
pred_probs = xg_reg.predict_proba(X_test)[:,1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-3f929c746988> in <module>
# ----> 1 pred_probs = xg_reg.predict_proba(X_test)[:,1]
#
# AttributeError: 'XGBRegressor' object has no attribute 'predict_proba'
